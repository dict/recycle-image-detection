# %%
# !touch 0.txt

# %%
import time

# %%
for idx in range(50):
    time.sleep(1)
    a = str(idx)+'.txt'
    b = str(idx+1)+'.txt'
    # !mv $a $b
    # !git add .
    # !git commit -m "temp"
    # !git push origin main
# Out:
# [main 961f2de] temp
#  3 files changed, 12 insertions(+)
#  create mode 100644 .ipynb_checkpoints/Untitled-checkpoint.ipynb
#  create mode 100644 1.txt
#  create mode 100644 Untitled.ipynb
# Enumerating objects: 7, done.
# Counting objects: 100% (7/7), done.
# Delta compression using up to 64 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (5/5), 466 bytes | 466.00 KiB/s, done.
# Total 5 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/dict/ai-grand-challenge-4th.git
#    278d3fa..961f2de  main -> main
# [main e6c47f7] temp
#  1 file changed, 0 insertions(+), 0 deletions(-)
#  rename 1.txt => 2.txt (100%)
# Enumerating objects: 3, done.
# Counting objects: 100% (3/3), done.
# Delta compression using up to 64 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (2/2), 212 bytes | 212.00 KiB/s, done.
# Total 2 (delta 1), reused 0 (delta 0)
# ...
